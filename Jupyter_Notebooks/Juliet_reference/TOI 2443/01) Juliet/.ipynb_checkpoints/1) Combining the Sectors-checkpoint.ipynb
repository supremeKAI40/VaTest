# %% [markdown]
# # Importing Libraries

# %%
import lightkurve as lk  # LightKurve Python Package to View & Process the Transit Light Curves
import numpy as np       # Numpy for Scientific Computing
import matplotlib.pyplot as plt # Matplotlib for Plotting the Garphs

import os

# %% [markdown]
# # Path to the files needed to Combine & Detrend

# %%
# Define the TOI ID of a Target
TOI_ID = '2443' # Only number i.e., if the target is TOI 111 then only write 111

# Provide a Path to the .fits files

os.chdir('E:/MAST TESS Data/TOI '+TOI_ID)
print(os.getcwd())

file_1 = lk.read('tess2020294194027-s0031-0000000318753380-0198-s_lc.fits').normalize()

os.chdir('C:/Users/computer/Exoplanets_Programing/FPP Calculator/Lightkurve & Juliet Code for Modeling/TOI '+TOI_ID)
print(os.getcwd())
# Out:
# E:\MAST TESS Data\TOI 2443
# C:\Users\computer\Exoplanets_Programing\FPP Calculator\Lightkurve & Juliet Code for Modeling\TOI 2443

# %% [markdown]
# # Combining the Sectors & Plot it

# %%
# Combine all available Light Curves
# Add or remove file_n based on the total number of files below
Combined_TOI = file_1
Combined_TOI.scatter()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %% [markdown]
# # Periodogram

# %%
# Create a Periodogram to find out the period of repeated occurrence
# In general find out the period of transit, Epoch time and Transit Durataion

pg = Combined_TOI.to_periodogram(method = 'bls', period = np.arange(1,20,0.01))
pg.plot()

time_period = pg.period_at_max_power
total_transit_time = pg.transit_time_at_max_power
transit_duration = pg.duration_at_max_power

print(" Orbital Period (d) : ", time_period, "\n Epoch Time (BTJD) : ", total_transit_time,\
      "\n Transit Duration (d) : ", transit_duration)
# Out:
#  Orbital Period (d) :  15.680000000000014 d
#  Epoch Time (BTJD) :  2148.0953192294864
#  Transit Duration (d) :  0.2 d

# %% [markdown]
# # Masking and Detrending

# %%
# Based on previous evaluated values we have to mask all the transits and need to de-trend the remaining portion
# In a view to avoide the stellar activity 

# Mask the transits 
# Paste below the data (period, epoch time, transit duration) calculated above.
masked_lc = Combined_TOI.create_transit_mask(period = 15.6692322098987, 
                                             transit_time = 2148.098617, 
                                             duration = 0.25)

# Detrending the out of transit part
flat_lc = Combined_TOI.flatten(mask = masked_lc)
flat_lc.scatter()

# Create the Periodogram of Detrended Light Curve
pg_flatten = flat_lc.to_periodogram(method = 'bls', period = np.arange(1,20,0.001))
pg_flatten.plot()

# Print the evaluated values
time_period = pg_flatten.period_at_max_power
transit_time = pg_flatten.transit_time_at_max_power
transit_duration = pg_flatten.duration_at_max_power
print("\n")
print(" Orbital Period (d) : ",time_period,"\n","Epoch Time (BTJD) : ",transit_time,\
      "\n","Transit Duration (d) : ", transit_duration)
# Out:
#  Orbital Period (d) :  15.674999999998384 d
#  Epoch Time (BTJD) :  2148.0953192294864
#  Transit Duration (d) :  0.2 d

# %% [markdown]
# # Plot the Folded Light Curve

# %%
# Fold the light curve based on calculated Time Period & Epoch Time
folded_lc = flat_lc.fold(period = 15.6692322098987, epoch_time = 2148.098617)

# Plot whole folded light curve
folded_lc.scatter()

# Focused on transit
folded_lc.scatter()
plt.xlim(-0.5,0.5)
# Out:
# (-0.5, 0.5)

# %% [markdown]
# # Saving the .fits File for further analysis

# %%
# Add columns pdcsap & pdcsap_err to the .fits file
# These two columns will be used while modeling as a raw data
pdcsap = flat_lc.flux
pdcsap_err = flat_lc.flux_err

# Save the File
processed_lc = flat_lc.to_fits(path = 'Detrended & Combined Lightcurves/Combined TOI '+TOI_ID+'.fits', \
                               overwrite = True, pdcsap_flux = pdcsap, pdcsap_flux_err = pdcsap_err)

# Open the file and print
Final_Light_Curve = lk.read('Detrended & Combined Lightcurves/Combined TOI '+TOI_ID+'.fits')
Final_Light_Curve
# Out:
# <TessLightCurve length=17254 LABEL="318753380" SECTOR=31 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time               flux        ...     mom_centr2     quality
#                                       ...
#       object            float64       ...      float64        int32
# ------------------ ------------------ ... ------------------ -------
# 2144.5203192294866 0.9999398194033922 ... 1377.9708751557434       0
# 2144.5217081466317  0.999569435728421 ... 1377.9699645138342       0
#  2144.523097063776  1.001576519970107 ... 1377.9708384589158       0
#   2144.52448598092 0.9998487705005946 ... 1377.9707729443644       0
#    2144.5258748976 0.9998786813882472 ...  1377.969373032966       0
# 2144.5272638147453 1.0008565092558297 ... 1377.9712565208367       0
# 2144.5286527318895 1.0003232054737088 ... 1377.9697260340852       0
#  2144.530041648569 1.0003708798313593 ... 1377.9713053571686       0
#  2144.531430565713 0.9997945361636017 ... 1377.9674421907282       0
#                ...                ... ...                ...     ...
# 2169.9367906529037  0.998982778942791 ... 1377.6741455674733       0
# 2169.9381794983465 1.0007737552148908 ... 1377.6651241506834       0
#  2169.939568343324 0.9996499533132012 ... 1377.6626618459984       0
# 2169.9409571887663 1.0003390233386098 ... 1377.6658325082428       0
#  2169.942346034209 1.0003290131286966 ... 1377.6686054212457       0
# 2169.9437348796514 1.0000504253371225 ... 1377.6722753296879       0
# 2169.9451237246285 0.9998431791981349 ...  1377.672784504526       0
# 2169.9465125700717 1.0002904582642231 ...   1377.67209058866       0
#  2169.947901415515  1.000139121022176 ...  1377.664103256672       0
# 2169.9492902609577 0.9998953898703299 ... 1377.6621765216464       0
